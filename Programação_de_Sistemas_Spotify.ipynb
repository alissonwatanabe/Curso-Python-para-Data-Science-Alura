# %% [markdown]
# <a href="https://colab.research.google.com/github/alissonwatanabe/Curso-Python-para-Data-Science-Alura/blob/main/Programa%C3%A7%C3%A3o_de_Sistemas_Spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import webbrowser
import urllib as url

class Musica(object):
    def __init__(self):
        pass

    def Nome(self):
        pass

def resposta():
    print("1-sim")
    print("2-não")
    resp =input()
    while resp != '1' and resp != '2':
        print("Valor inválido, os valores devem ser 1 ou 2")
        print("Por favor, insira um valor válido")
        resp = input()
    return int(resp)

def fim():
        os.system('cls')
        print("")
        print("Obrigado por jogar comigo!")
        print("Até a próxima")
        input()
        os.system('cls')

class rock_classico(Musica):

    def Nome(self):
        url="https://www.youtube.com/watch?v=u1V8YRJnr4Q"
        webbrowser.open(url)
    pass

    def pergunta(self):
        print("É consicderado Clássico?")


class rock_pesado(Musica):

    def Nome(self):
        url="https://www.youtube.com/watch?v=F_6IjeprfEs"
        webbrowser.open(url)
    pass

    def pergunta(self):
        print("Possui muitos gritos?")

class rock_pop(Musica):

    def Nome(self):
        url="https://www.youtube.com/watch?v=jabmx3QoJGA"
        webbrowser.open(url)
    pass

class funk_proibidorj(Musica):

    def Nome(self):
        url="https://www.youtube.com/watch?v=bNmgFfmN8WQ&list=PLhOIJyyqQ8tmxXYAh78xA1ZeLFEQJN4Bm"
        webbrowser.open(url)
    pass 
    
    def pergunta(self):
        print("É muito ouvido no RJ?")
  

class funk_proibidosp(Musica):

    def Nome(self):
        url="https://www.youtube.com/watch?v=opKlNp1zCKQ"
        webbrowser.open(url)
    pass

class funk_pop(Musica):

    def Nome(self):
        url="https://www.youtube.com/watch?v=u1V8YRJnr4Q"
        webbrowser.open(url)
    pass

class sertanejo_universitario(Musica):

    def Nome(self):
        url="https://www.youtube.com/watch?v=_SjTFD9qVuE"
        webbrowser.open(url)
    pass

    def pergunta(self):
        print("É muito ouvido pelos jovens?")

class sertanejo_dancante(Musica):

    def Nome(self):
        url="https://www.youtube.com/watch?v=dhK9IT04uTU"
        webbrowser.open(url)
    pass

class sertanejo_raiz(Musica):

    def Nome(self):
        url="https://www.youtube.com/watch?v=Y91aHs8QI7M&list=OLAK5uy_m36cM0Ba5rfk_7ykbVVSSCR69IKcoZQKY"
        webbrowser.open(url)
    pass



print("")
print("Pense em uma música que você gostaria de ouvir")
print("")
print("")
input("Tecle ENTER para começar")

print("Seu estilo de música é considerado pesado?")
if resposta()==1:
    print("Costuma-se ouvir em volume alto?")
    if resposta()==1:
        m1 = rock_classico()
        m1.pergunta()
        if resposta()==1:
            m1=rock_classico()
            m1.Nome()
            fim()
        else:
           m1=rock_pesado()
           m1.pergunta()
           if resposta()==1:
              m1=rock_pesado()
              m1.Nome()
              fim()
           else:
              m1=rock_pop()
              m1.Nome()
              fim()
    else:
        print("Possui letras obscenas?")
        if resposta()==1:
            m1=funk_proibidorj()
            m1=pergunta()
            if resposta()==1:
                m1=funk_proibidorj()
                m1.Nome()
            else:
                m1=funk_proibidosp()
                m1.Nome()
                fim()
        else:
            m1=funk_pop()
            m1=Nome()
            fim()

else:
    print("É muito popular??")
    if resposta()==1:
        m1=sertanejo_universitario()
        m1.pergunta()
        if resposta()==1:
            m1=sertanejo_universitario()
            m1.Nome()
            fim()
        else:
            m1=sertanejo_dancante()
            m1.Nome()
            fim()
    else:
        m1=sertanejo_universitario()
        m1.Nome()
# Out:
# Pense em uma música que você gostaria de ouvir
#
#
# Tecle ENTER para começar
# Seu estilo de música é considerado pesado?
# 1-sim
# 2-não
# 1
# Costuma-se ouvir em volume alto?
# 1-sim
# 2-não
# 1
# É consicderado Clássico?
# 1-sim
# 2-não
# 1
# Sua música é: RC
#
# Obrigado por jogar comigo!
# Até a próxima

# %%
class Musica:
    def __init__(self, estilo, epoca, ocasiao):
        estilo = input("qual estilo você ouve: ")
        self.estilo = estilo
        self.__ocasiao = ocasiao

class rock_classico(Musica):
    def rc():
      print("sua musica é um rock cássico")
    pass

class rock_pauleira(Musica):
    def rp():
      rock
      print("sua musica é um rock pauleira")
    pass

class rock_progressivo(Musica):
    def rock_pauleira():
      print("sua musica é um rock pauleira")
    pass

Musica.estilo = 'rock'
Musica. ocasiao = 'dormir'

print(Musica)
# Out:
# <class '__main__.Musica'>
